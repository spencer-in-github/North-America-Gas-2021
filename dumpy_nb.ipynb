# %%
import pandas as pd
import numpy as np

# %%
PATH_RESULT_SHEET             = "/Users/spencerzhang/GitHub/PhD/North-America-Gas-2021/Result Data/US_GAS_2022_RESULT_cleaned.csv"
raw_result = pd.read_csv(PATH_RESULT_SHEET)

result = raw_result[["Field properties Field name NA",
                    "Field properties Oil production volume bbl/d",
                    "Production practices Gas-to-oil ratio (GOR) scf/bbl oil",
                    "Lifecycle GHG emissions Total CO2 sequestered gCO2eq/MJ"]]

# %%
column_names = pd.DataFrame(raw_result.columns)

# %%
result["gas volume"] = result.loc["Field properties Oil production volume bbl/d"] * result["Production practices Gas-to-oil ratio (GOR) scf/bbl oil"]

# oil BBL
# gor scf/bbl
# gas = gor * oil / 1000 (MCF)
# Out:
# /var/folders/g6/rg58f3ds4jj7c23g1xr0j25m0000gn/T/ipykernel_37954/874036462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result["gas volume"] = result["Field properties Oil production volume bbl/d"] * result["Production practices Gas-to-oil ratio (GOR) scf/bbl oil"]

# %%
result.to_excel("inspect_gas_vs_high_CI.xlsx")

# %%
import plotly.express as px

fig = px.scatter(result, x="gas volume", y="Lifecycle GHG emissions Total CO2 sequestered gCO2eq/MJ")
fig.show()

# %%
fig = px.scatter(result, x="Field properties Oil production volume bbl/d", y = "Lifecycle GHG emissions Total CO2 sequestered gCO2eq/MJ")
fig.show()

# %%
fig = px.scatter(result, x="Production practices Gas-to-oil ratio (GOR) scf/bbl oil", y = "Lifecycle GHG emissions Total CO2 sequestered gCO2eq/MJ")
fig.show()
