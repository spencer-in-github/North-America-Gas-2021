# %% [markdown]
# # A notebook for dumpy result inspection and plotting
#
# Author:   Spencer Zhang
#
# Date:     November 30, 2023

# %%
# packages
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# path
PATH_RESULT_SHEET             = "/Users/spencerzhang/GitHub/PhD/North-America-Gas-2021/NAG run 20231128/NAG_CI_20231128_with_input_no_sf.xlsx"

# raw data file
raw_result = pd.read_excel(PATH_RESULT_SHEET)

# %% [markdown]
# # Scatterplot

# %% [markdown]
# ## scatter Gas-CI

# %%
fig = px.scatter(raw_result, x="Annual_Gas", y="CI_gCO2_MJ", color = "Check")
fig.show()

# %% [markdown]
# ## scatter Oil-CI

# %%
fig = px.scatter(raw_result, x="Annual_Oil", y="CI_gCO2_MJ", color = "Check")
fig.show()

# %% [markdown]
# ## scatter C1 fraction - CI

# %%
fig = px.scatter(raw_result, x="C1", y="CI_gCO2_MJ", color = "Check")
fig.show()
